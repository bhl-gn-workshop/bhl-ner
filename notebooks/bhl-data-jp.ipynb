# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

    
from src.gRPC.gRPC_client import process

# %%
bhl_names = process()

# %%
bhl_names
# Out:
# ['Planorbis bicarinatus',
#  'Helix rufa',
#  'Megaspira',
#  'Gadus',
#  'Unio',
#  'Vivipara',
#  'Physa gyrina',
#  'Brachiopoda',
#  'Mollusca',
#  'Paladilhia',
#  'Moitessieria',
#  'Tridacna elongata',
#  'Physa heterostropha',
#  'Spirialis',
#  'Mollusca',
#  'Columna',
#  'Septifer',
#  'Mollusca',
#  'Mollusca',
#  'Megaspira',
#  'Gadus',
#  'Unio',
#  'Partula',
#  'Planorbis bicarinatus',
#  'Mollusca',
#  'Vivipara',
#  'Mollusca',
#  'Physa gyrina',
#  'Mollusca',
#  'Columna',
#  'Septifer',
#  'Mollusca',
#  'Scalaria',
#  'Bulimus',
#  'Planorbis',
#  'Melantho',
#  'Integra',
#  'Helicidae',
#  'A. verrucosa',
#  'Lithasia fuliginosa',
#  'Pleurocera bicinctum',
#  'Gon. luteola',
#  'Goniobasis',
#  'G. porrecta',
#  'Physa',
#  'Conns tulipa',
#  'Ph. venusia',
#  'Ph. diaphana',
#  'Physa oleacea',
#  'Primeana',
#  'Physa brevispira',
#  'Nason',
#  'Parva',
#  'Gyrina',
#  'Integra',
#  'Mollusca',
#  'Vivipara',
#  'V. contecta',
#  'V. intertexta',
#  'Australis',
#  'Hemisinus',
#  'Physa',
#  'Isidora',
#  'Physa acutispira',
#  'Bulinus',
#  'Bulinus hypnorum',
#  'Ph. virginea',
#  'Planorbis',
#  'Esperanza',
#  'Pi. lucidus',
#  'Pi. contortus',
#  'Planorbis',
#  'Planorbula',
#  'Pi. armigerus',
#  'Lymnea',
#  'Lymnea',
#  'Amnicola',
#  'Exilis',
#  'Helix tudiculata',
#  'Helix strigosa',
#  'Helix fulva',
#  'Helix arborea',
#  'Helix minuscula',
#  'Goniobasis',
#  'G. procissa',
#  'G. varians',
#  'G. decorata',
#  'O. decorata',
#  'O. granata',
#  'G. flavescens',
#  'G. catenaria',
#  'G. catenoides',
#  'G. papulosa',
#  'G. inclinans',
#  'G. arachnoidea',
#  'G. carinifera',
#  'G. vittata',
#  'G. abbreviata',
#  'G. vesicula',
#  'G. obesa',
#  'G. blanda',
#  'G. carinocostata',
#  'G. perstriata',
#  'G. obtusa',
#  'G. interveniens',
#  'G. olivella',
#  'G. interrupta',
#  'G. crispa',
#  'G. mediocris',
#  'G. laqueata',
#  'O. monozonalis',
#  'G. induta',
#  'G. versipellis',
#  'G. laqueata',
#  'G. gracilis',
#  'G. paucicosta',
#  'G. tenebrosa',
#  'G. coracina',
#  'G. intersita',
#  'G. blanda',
#  'G. nitens',
#  'G. mutata',
#  'G. suturalis',
#  'G. mutabilis',
#  'G. mutabilis',
#  'Costifera',
#  'G. inconstans',
#  'G. continens',
#  'O. proletaria',
#  'G. viridicata',
#  'G. purpurella',
#  'G. semicostata',
#  'G. dislocata',
#  'Q. dislocata',
#  'G. paupercula',
#  'Corneola',
#  'G. nassula',
#  'G. cinerella',
#  'G. caliginosa',
#  'G. nodulosa',
#  'G. difficilis',
#  'G. sparus',
#  'G. cancellata',
#  'G. athleta',
#  'G. curvicostata',
#  'G. densecostata',
#  'G. tripartita',
#  'G. decora',
#  'G. crebricostata',
#  'G. acuta',
#  'G. subcylindracea',
#  'G. baculum',
#  'G. concinna',
#  'G. eliminata',
#  'G. teres',
#  'O. terebralis',
#  'G. gracillima',
#  'G. plicifera',
#  'G. silicula',
#  'G. rudens',
#  'G. nigrina',
#  'G. rubiginosa',
#  'G. trochiformis',
#  'G. cristata',
#  'G. cruda',
#  'G. expansa',
#  'G. casta',
#  'G. subrhombica',
#  'G. rhombica',
#  'G. angulata',
#  'G. intercedens',
#  'G. cubicoides',
#  'G. pallidula',
#  'G. vicina',
#  'Marietta',
#  'G. modesta',
#  'G. infuscata',
#  'G. fraterna',
#  'G. acutocarinata',
#  'O. pagodiformis',
#  'G. torulosa',
#  'G. tabulata',
#  'G. subangulata',
#  'G. symmetrica',
#  'G. nigrocincta',
#  'G. tecta',
#  'O. marella',
#  'G. hybrida',
#  'G. fuscocincta',
#  'G. aterina',
#  'G. ebenum',
#  'G. auricoma',
#  'G. glabra',
#  'G. graminea',
#  'G. gibbosa',
#  'Sciota',
#  'Georgiana',
#  'G. abrupta',
#  'G. depygis',
#  'G. livescens',
#  'G. napella',
#  'G. torta',
#  'Cylindrella',
#  'G. virens',
#  'Newberryi',
#  'Newberryi',
#  'G. infantula',
#  'G. pulchella',
#  'M. depygis',
#  'G. cinerea',
#  'G. gracilior',
#  'G. translucens',
#  'Ovoidea',
#  'G. grata',
#  'G. quadricincta',
#  'G. grata',
#  'G. flava',
#  'G. tenebrovittata',
#  'G. tenera',
#  'G. pallescens',
#  'G. inosculata',
#  'G. circumlineata',
#  'G. parva',
#  'G. sordida',
#  'O. plebeia',
#  'G. castanea',
#  'G. adusta',
#  'Q. funebralis',
#  'G. furva',
#  'G. dubiosa',
#  'G. interlineata',
#  'G. brevispira',
#  'G. semicarinata',
#  'G. semicarinata',
#  'O. inornata',
#  'G. elaia',
#  'G. curvilabris',
#  'G. informis',
#  'G. vittatella',
#  'G. nigrina',
#  'G. rufescens',
#  'Virginica',
#  'G. sulcosa',
#  'Pleurocera',
#  'G. latitans',
#  'G. sculptilis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Jleux rufa',
#  'Helix thyroides',
#  'H. thyroides',
#  'H. thyroides',
#  'H. rufa',
#  'H. thyroides',
#  'Helix rufa',
#  'Ii. thyroides',
#  'Subordo',
#  'Geomelania',
#  'Chittya',
#  'Truncatella',
#  'Oceanica',
#  'Subordo',
#  'Oceanica',
#  'Cyclophorus',
#  'Megalomastoma',
#  'Oceanica',
#  'Hydrocena',
#  'Cyclostomus',
#  'Tudora',
#  'Choanopoma',
#  'Ctenopoma',
#  'Diplopoma',
#  'Cistula',
#  'Chondropoma',
#  'Opara',
#  'Stoastoma',
#  'Bourciera',
#  'Schasicheila',
#  'Cijdotus translucidus',
#  'Chondropoma',
#  'Helicina suhglohulosa',
#  'Truncatella',
#  'Subordo',
#  'Truncatella',
#  'Subordo',
#  'Cyclotus',
#  'Costarica',
#  'Megalomastoma',
#  'Adamsiella',
#  'Tudora',
#  'Cistula',
#  'Tamsiana',
#  'Chondropoma',
#  'Cumana',
#  'Cumana',
#  'Bourciera',
#  'Trochatella',
#  'Helicina',
#  'Tamsiana',
#  'Columbiana',
#  'Chryseis',
#  'Schasicheila',
#  'Alcadia',
#  'Cyclotus',
#  'Megaspira',
#  'Pupa elatior',
#  'Balea',
#  'Megasjiira elatior',
#  'Megaspira',
#  'Nassa',
#  'Bulliopsis',
#  'N. quadrata',
#  'Bullia',
#  'Integra',
#  'Buccinum integrum',
#  'Ovata',
#  'Subcylindrica',
#  'N. quadrata',
#  'Volutifusus',
#  'Valuta',
#  'Voluta',
#  'Voluta',
#  'V. typus',
#  'V. aurisleporis',
#  'Voluta',
#  'Junonia',
#  'Scaphella',
#  'Valuta',
#  'Typus',
#  'Cancellaria',
#  'G. alternata',
#  'Plagiostoma',
#  'C. plagiostoma',
#  'Scalarina',
#  'Busycon',
#  'C. annularia',
#  'Niso',
#  'Lineata',
#  'Bonellia lineata',
#  'Longidens',
#  'Melampus longidens',
#  'Ensiphorus',
#  'Tifata',
#  'Saxicava',
#  'Periploma',
#  'P. papyratia',
#  'Anatina',
#  'P. alia',
#  'Thracia',
#  'Saxicava',
#  'Mya arenaria',
#  'Capillaria',
#  'Tellina',
#  'Angulus',
#  'T. polita',
#  'Tellinella',
#  'Capillifera',
#  'Tellinella',
#  'Compsonema',
#  'A. concentrica',
#  'A. castanea',
#  'Distans',
#  'A. distans',
#  'Carditamera',
#  'Aculeata',
#  'Lithophaga',
#  'Ostrea',
#  'Nassa quadrata',
#  'Volutifusus',
#  'Typus',
#  'Nassa',
#  'Integra',
#  'Cancellaria perspectiva',
#  'Busycon alveatum',
#  'Cancellaria biplicifera',
#  'Spisula capillaria',
#  'Mysia parilis',
#  'Tellinella capillifera',
#  'Thracia',
#  'Lithophaga subalveata',
#  'Carditamera aculeata',
#  'Saxicava parilis',
#  'Cancellaria alternata',
#  'Periploma papyratia',
#  'Anatina',
#  'Tellina peracuta',
#  'Tifata longidens',
#  'Niso lineata',
#  'Astarte distans',
#  'Cancellaria plagiostoma',
#  'Cancellaria scalarina',
#  'Cypr�a annulifera',
#  'Gadus',
#  'Gadus',
#  'Helonyx',
#  'O. gadus',
#  'Ditrupa',
#  'Ij. subcoarctata',
#  'Ditrupa',
#  'Ecphora',
#  'Pyrula',
#  'Cancellaria ampullacea',
#  'G. leporina',
#  'Trochita',
#  'Nerita',
#  'Leptonotis',
#  'Velutina',
#  'Velutina',
#  'Velutina',
#  'Cumingia',
#  'Borealis',
#  'G. tellinoides',
#  'Corbula',
#  'C. alia',
#  'C. alta',
#  'Macoma',
#  'Virginiana',
#  'M. lusoria',
#  'T. lusoria',
#  'Anomiidae',
#  'Diploschiza',
#  'Anomia',
#  'Terebratulina',
#  'Filosa',
#  'T. gracilis',
#  'T. gracilis',
#  'Lacunaria',
#  'Natica',
#  'Erecta',
#  'Natica',
#  'Cyclomera',
#  'Baculites',
#  'Vivipara',
#  'Paludina suhliiieata',
#  'Ceylonica',
#  'V. amplior',
#  'V. dissimilis',
#  'Melania tetrica',
#  'Melania tetrica',
#  'Australis',
#  'Melania',
#  'M. tetrica',
#  'Amphipeplea perlevis',
#  'Lymnea perlevis',
#  'Physa pectorosa',
#  'Ph. pectorosa',
#  'Physa',
#  'Australiana',
#  'Australiana',
#  'Realia ochrostoma',
#  'Realia variabilis',
#  'Realia scalariformis',
#  'Realia affinis',
#  'Realia',
#  'Pupoidea scalariformis',
#  'Pterocyclos parva',
#  'Helicina',
#  'Pacifica',
#  'Voluta',
#  'Doridopsis',
#  'Stilifer',
#  'Leptoconchus',
#  'Terebra',
#  'Agnatha',
#  'Pulmonata',
#  'Planorbis',
#  'Pelagica',
#  'Terrestria',
#  'Paludina',
#  'Turritella',
#  'Parasitica',
#  'Vermetus',
#  'Hipponyx',
#  'Pelagica',
#  'Natica',
#  'Voluta',
#  'Marginella',
#  'Harpa',
#  'Oliva',
#  'Nassa',
#  'Buccinum',
#  'Fasciolaria',
#  'Fusus',
#  'Cancellaria',
#  'Terebra',
#  'Clionella',
#  'Acephala',
#  'Turbo marmoratus',
#  'Terrestria',
#  'Helicina',
#  'Neritina',
#  'Nerita',
#  'Trochoidea',
#  'Haliotis',
#  'Fissurellidea',
#  'Acephala',
#  'Mytilacea',
#  'Apoda',
#  'Architectonica cognata',
#  'Venericardia planicosta',
#  'Aturia zic-zac',
#  'Aturia',
#  'Fusus',
#  'Amauro�psis alveata',
#  'Dentalinm',
#  'Mactra',
#  'Avicula pellucida',
#  'Nucula',
#  'Acila',
#  'Leda protexta',
#  'Ammonites',
#  'Aturia',
#  'A. angustata',
#  'Turritella',
#  'Venus varians',
#  'Pugnellus hamulus',
#  'Ammonites',
#  'Cardita',
#  'Ammonites',
#  'Fusus',
#  'Californicus',
#  'Volutilithes jsfavarroensis',
#  'Rostellites',
#  'Fusus',
#  'Hemifusus',
#  'Perissolax',
#  'Perissolax',
#  'Fusus',
#  'Tudicla',
#  'Perissolax hrevirosfris',
#  'Perissolax',
#  'Naticina',
#  'Ammonites',
#  'Amauropsis alveata',
#  'Natica alveata',
#  'Chemnitzia',
#  'Jjosinia elevata',
#  'Dosiniopsis',
#  'Dosinia',
#  'Meretrix',
#  'Ficus mamillatus',
#  'Dione ovata',
#  'Meelda sella',
#  'Cyprina',
#  'M. navis',
#  'Yoldia',
#  'Mactra',
#  'Nucula tnincata',
#  'Tamiosoma gregaria',
#  'Discina',
#  'Froducta gracilis',
#  'Spirigera',
#  'Spirifera',
#  'Spiriferina',
#  'Rhynchonella unica',
#  'Retzia',
#  'Centronella',
#  'Ostrea patercula',
#  'Pterinea spinalata',
#  'Finna',
#  'Myalina',
#  'Sangainolites strigatus',
#  'Sanyuinolaria rostrata',
#  'Conularia',
#  'Newberryi',
#  'Optoma undata',
#  'Pleurotomaria quinque sulcata',
#  'Tellina halthica',
#  'Eegistoma ambiguum',
#  'Pleurotoma',
#  'Clathurella',
#  'Periploma',
#  'Letourneuxiana',
#  'Mesodesma',
#  'Mactra amygdala',
#  'Malacologique terrestre',
#  'Limopsis',
#  'Limopsis',
#  'Mollusca',
#  'Helix sculptilis',
#  'Paludina',
#  'Planorbis bicarinatus',
#  'Helix rufa',
#  'Megaspira',
#  'Gadus',
#  'Felix',
#  'Hamites',
#  'Ammonites',
#  'Helicoceras',
#  'Crioceras',
#  'Ancyloceras',
#  'Baculites',
#  'Aporrhais angulata',
#  'Dosiniopsis aua',
#  'Dosiniopsis',
#  'Dosinia',
#  'Dosinia',
#  'Dosiniopsis',
#  'Cyprimeria',
#  'Dosinia',
#  'Venilia',
#  'Cypricardia',
#  'Dosinia',
#  'Venericardia',
#  'Venericardia came',
#  'Meekia sella',
#  'Gyprina bisecta',
#  'Fasciolaria elongata',
#  'Perissolax',
#  'Busycon',
#  'Levifusus traheatus',
#  'Cardita',
#  'G. granigera',
#  'Perissolax brevirostris',
#  'Ficus mamillatus',
#  'Ficopsis',
#  'Hemifusus',
#  'Amauropsis alveata',
#  'Ampullina',
#  'Globulus',
#  'Ampullina',
#  'Natica',
#  'Lunatia',
#  'A. alveata',
#  'Venericardia',
#  'V. planicosta',
#  'F. planicosta',
#  'Dosinia',
#  'D. inflata',
#  'Cyprinella',
#  'Dosiniopsis',
#  'Oyprina planata',
#  'Vemis plana',
#  'D. alta',
#  'D. alta',
#  'Hamites',
#  'Ancylocerus',
#  'Hamites',
#  'Neptunea curvirostris',
#  'Priscoficus',
#  'Cephalopoda',
#  'Nautilus perforatus',
#  'N. perforatus',
#  'Hercoglossa',
#  'Aturia',
#  'Aturia',
#  'Cephalopoda',
#  'Aturia',
#  'Aturia',
#  'Cimomia',
#  'Anchura',
#  'Drepanochilus',
#  'R. alpina',
#  'R. carinata',
#  'R. calcarata',
#  'R. tricostata',
#  'R. carinella',
#  'R. ornata',
#  'Requieniana',
#  'Drepanochilus',
#  'Cyprimeria',
#  'Arcopagia',
#  'C. densata',
#  'Arcojmgia densata',
#  'G. excavata',
#  'Gytherea excavata',
#  'Peruviana',
#  'G. concentrica',
#  'Girce concentrica',
#  'G. cretacea',
#  'Dosinia cretacea',
#  'Arcopagia numismalis',
#  'A. rotundata',
#  'Venilia',
#  'V. humilis',
#  'V. trapezoidea',
#  'V. trigona',
#  'Jypricardia testacea',
#  'V. bifida',
#  'Cyprina bifida',
#  'V. crassidentata',
#  'Cyp�rina crassidentata',
#  'V. cycladiformis',
#  'Cyprina cycladiformis',
#  'V. planidorsata',
#  'Isocardia planidorsata',
#  'Pseudocardia',
#  'G. apertum',
#  'C. conjugens',
#  'V. quadrata',
#  'V. tenuicostata',
#  'V. constantii',
#  'V. cottaldina',
#  'Orthonota',
#  'Sanguinolites anguliferus',
#  'S. clava',
#  'Plectosolen',
#  'Solen gracilis',
#  'S. obliquus',
#  'Gultellus affinis',
#  'S. proximus',
#  'S. protextus',
#  'Crassatella',
#  'Planata',
#  'Curta',
#  'G. curta',
#  'Mercenaria',
#  'Obtusa',
#  'Arcinella',
#  'Arcinella coenuta',
#  'Ghama arcinella',
#  'Diploschiza',
#  'D. cretacea',
#  'Terebeatulina filosa',
#  'T. gracilis',
#  'Cumingia',
#  'Gumingia tellinoides',
#  'C. tellinoides',
#  'Saxicava',
#  'Fragilis',
#  'Anatina borealis',
#  'P. papyratia',
#  'P. alta',
#  'P. papyratia',
#  'Crassatella',
#  'Carditamera',
#  'Ecphora',
#  'Unio',
#  'Unio depygis',
#  'Vivipara',
#  'Vivipara',
#  'Margaretta',
#  'Paludina elongata',
#  'Helix vivipara',
#  'Vivipara',
#  'Tulotoma',
#  'Lioplax',
#  'V. vivipara',
#  'Y. lineata',
#  'V. intertexta',
#  'V. lineata',
#  'V. vivipara',
#  'V. fasciata',
#  'V. pyramidalis',
#  'Vivipara',
#  'V. suprafasciata',
#  'V. vivipara',
#  'Y. lineata',
#  'Mollusca',
#  'Melania pr�mordica',
#  'M. gloriosa',
#  'Melania',
#  'L. umbrosa',
#  'L. umbrosa',
#  'Physa heterostropha',
#  'Vivipara decisa',
#  'Unio complanatus',
#  'U. radiatus',
#  'Planorbis circumstriatus',
#  'Gyraulus',
#  'Planorhula armigera',
#  'Lym. umbrosa',
#  'L. desidiosa',
#  'Physa',
#  'Gyrina',
#  'Paludina scalaris',
#  'Goniobasis',
#  'G. cylindracea',
#  'G. pupoidea',
#  'G. cylindracea',
#  'G. lita',
#  'G. fallax',
#  'G. inosculata',
#  'G. fallax',
#  'G. rara',
#  'O. fallax',
#  'G. punicea',
#  'G. pudica',
#  'O. olivula',
#  'G. fabalis',
#  'O. pudica',
#  'G. fumea',
#  'G. aequa',
#  'G. solidula',
#  'Olivula',
#  'G. fascinans',
#  'O. fascinans',
#  'G. pupaeformis',
#  'G. clausa',
#  'G. crepera',
#  'G. abscida',
#  'G. crepera',
#  'Hayesiana',
#  'G. arctata',
#  'G. ampla',
#  'G. ambusta',
#  'G. harpa',
#  'O. textilosa',
#  'G. oliva',
#  'G. grisea',
#  'G. culta',
#  'O. suavis',
#  'G. luteola',
#  'G. gravida',
#  'G. variata',
#  'G. ovalis',
#  'Q. orbicula',
#  'G. virgulata',
#  'G. inflata',
#  'G. fusiformis',
#  'G. bellula',
#  'G. calculoides',
#  'G. basalis',
#  'O. fusiformis',
#  'G. ellipsoides',
#  'G. excavata',
#  'G. purpurea',
#  'G. quadrivittata',
#  'G. propria',
#  'G. negata',
#  'G. impressa',
#  'G. laeta',
#  'G. pergrata',
#  'G. capillaris',
#  'G. impressa',
#  'Goniobasis',
#  'Goniobasis',
#  'Goniobasis',
#  'Anculosa',
#  'A. plicata',
#  'A. canalifera',
#  'Costata',
#  'A. rubiginosa',
#  'A. dissimilis',
#  'Anculosa',
#  'Mudalia',
#  'A- carinata',
#  'A. monodontoides',
#  'A. affinis',
#  'A. littorina',
#  'A. corpulenta',
#  'A. canalifera',
#  'A. melanoides',
#  'A. turgida',
#  'A. trilineata',
#  'A. viridis',
#  'A. subglobosa',
#  'A. angulata',
#  'A. pinguis',
#  'A. contorta',
#  'A. vittata',
#  'A. planospira',
#  'A. ampla',
#  'A. ornata',
#  'A. patula',
#  'A. viridula',
#  'A. ligata',
#  'Anculosa',
#  'Anculosa',
#  'Anculosa',
#  'Melania depygis',
#  'Gyrotoma',
#  'Melania depygis',
#  'Gyrotoma',
#  'Ancylotus',
#  'Pachychilus',
#  'Mollusca',
#  'Pirena',
#  'Melanopsis',
#  'Pachychilus',
#  'Anculosa',
#  'Bulimus',
#  'Ennea',
#  'Bulimus',
#  'Oleacina',
#  'Geomelania',
#  'Chittya',
#  'Cyclotus',
#  'Megalomastoma',
#  'Bourciera',
#  'Hydrocena',
#  'Tudora',
#  'Schasicheila',
#  'Bourciera',
#  'Hydrocena',
#  'Bulimus',
#  'Bourciera',
#  'Hydrocena',
#  'Diplopoma',
#  'Schasicheila',
#  'Ghondropoma dentatum',
#  'Helicina subglohulosa',
#  'Truncatella',
#  'Littorales',
#  'Helicina rugosa',
#  'Meyalomastoma procer',
#  'Geomelania',
#  'Stoastoma',
#  'Lucidella',
#  'Trochatella',
#  'Tudora',
#  'Geomelania',
#  'Stoastoma',
#  'Lucidella',
#  'Megalomastoma',
#  'Licina',
#  'Helicina rugosa',
#  'Tudora pupieformis',
#  'Megalomastoma',
#  'Licina',
#  'Chondropoma',
#  'Lucidella',
#  'Trochatella',
#  'Lucidella',
#  'Chondropoma',
#  'Choanopoma sulculosum',
#  'Helicina fasciata',
#  'Cyclotus',
#  'Megalomastoma',
#  'Choanopoma',
#  'Adamsiella alone',
#  'Helicina',
#  'Gijdotus translucidus',
#  'Helicina',
#  'Helicina fasciata',
#  'Tudora megacheila',
#  'Helix pentodon',
#  'Bulimus elongatus',
#  'Strophia',
#  'Anodon',
#  'Anodon subgibbosa',
#  'Anodon inornata',
#  'Unio opalinus',
#  'Unio',
#  'Unio gibbosus',
#  'Goniobasis cingenda',
#  'Virginica',
#  'B. tenue',
#  'B. ciliatum',
#  'Buccinum',
#  'B. ovoides',
#  'Mollusca',
#  'Buccinum undatum',
#  'Fusus',
#  'Mangelia',
#  'Liomesus',
#  'Buccinum',
#  'L. ovoides',
#  'Buccinum',
#  'B. glaciale',
#  'B. angulosum',
#  'B. striatum',
#  'B. ciliatum',
#  'Buccinum',
#  'B. tenue',
#  'B. undulatum',
#  'B. undatum',
#  'Columella',
#  'Columella',
#  'B. cyaneum',
#  'Beatricea',
#  'Lingula elegantula',
#  'Orthisina',
#  'Strophomena semiovalis',
#  'Plectambonites glabra',
#  'Lepicena sericea',
#  'Plectambonites area',
#  'Lentmna transversalis',
#  'Strophomena alterniradiata',
#  'Plectambonites tenera',
#  'Brachyprion',
#  'Leptsena quadrilatera',
#  'Strophomena depressa',
#  'Brachyprion geiiiculatum',
#  'Platystrophia regularis',
#  'Orthis media',
#  'Atrypa impressa',
#  'A. reticularis',
#  'Orthis',
#  'Athyris turgida',
#  'Orthis rhynconelliformis',
#  'Spirifer tenuistriatus',
#  'Amnicola',
#  'Bithinia',
#  'Bythinia',
#  'Rissoina',
#  'Alvania',
#  'Onoba',
#  'Setia',
#  'Ceratia',
#  ...]

# %%
text = str(bhl_names)
text
# Out:
# "['Planorbis bicarinatus', 'Helix rufa', 'Megaspira', 'Gadus', 'Unio', 'Vivipara', 'Physa gyrina', 'Brachiopoda', 'Mollusca', 'Paladilhia', 'Moitessieria', 'Tridacna elongata', 'Physa heterostropha', 'Spirialis', 'Mollusca', 'Columna', 'Septifer', 'Mollusca', 'Mollusca', 'Megaspira', 'Gadus', 'Unio', 'Partula', 'Planorbis bicarinatus', 'Mollusca', 'Vivipara', 'Mollusca', 'Physa gyrina', 'Mollusca', 'Columna', 'Septifer', 'Mollusca', 'Scalaria', 'Bulimus', 'Planorbis', 'Melantho', 'Integra', 'Helicidae', 'A. verrucosa', 'Lithasia fuliginosa', 'Pleurocera bicinctum', 'Gon. luteola', 'Goniobasis', 'G. porrecta', 'Physa', 'Conns tulipa', 'Ph. venusia', 'Ph. diaphana', 'Physa oleacea', 'Primeana', 'Physa brevispira', 'Nason', 'Parva', 'Gyrina', 'Integra', 'Mollusca', 'Vivipara', 'V. contecta', 'V. intertexta', 'Australis', 'Hemisinus', 'Physa', 'Isidora', 'Physa acutispira', 'Bulinus', 'Bulinus hypnorum', 'Ph. virginea', 'Planorbis', 'Esperanza', 'Pi. lucidus', 'Pi. contortus', 'Planorbis', 'Planorbula', 'Pi. armigerus', 'Lymnea', 'Lymnea', 'Amnicola', 'Exilis', 'Helix tudiculata', 'Helix strigosa', 'Helix fulva', 'Helix arborea', 'Helix minuscula', 'Goniobasis', 'G. procissa', 'G. varians', 'G. decorata', 'O. decorata', 'O. granata', 'G. flavescens', 'G. catenaria', 'G. catenoides', 'G. papulosa', 'G. inclinans', 'G. arachnoidea', 'G. carinifera', 'G. vittata', 'G. abbreviata', 'G. vesicula', 'G. obesa', 'G. blanda', 'G. carinocostata', 'G. perstriata', 'G. obtusa', 'G. interveniens', 'G. olivella', 'G. interrupta', 'G. crispa', 'G. mediocris', 'G. laqueata', 'O. monozonalis', 'G. induta', 'G. versipellis', 'G. laqueata', 'G. gracilis', 'G. paucicosta', 'G. tenebrosa', 'G. coracina', 'G. intersita', 'G. blanda', 'G. nitens', 'G. mutata', 'G. suturalis', 'G. mutabilis', 'G. mutabilis', 'Costifera', 'G. inconstans', 'G. continens', 'O. proletaria', 'G. viridicata', 'G. purpurella', 'G. semicostata', 'G. dislocata', 'Q. dislocata', 'G. paupercula', 'Corneola', 'G. nassula', 'G. cinerella', 'G. caliginosa', 'G. nodulosa', 'G. difficilis', 'G. sparus', 'G. cancellata', 'G. athleta', 'G. curvicostata', 'G. densecostata', 'G. tripartita', 'G. decora', 'G. crebricostata', 'G. acuta', 'G. subcylindracea', 'G. baculum', 'G. concinna', 'G. eliminata', 'G. teres', 'O. terebralis', 'G. gracillima', 'G. plicifera', 'G. silicula', 'G. rudens', 'G. nigrina', 'G. rubiginosa', 'G. trochiformis', 'G. cristata', 'G. cruda', 'G. expansa', 'G. casta', 'G. subrhombica', 'G. rhombica', 'G. angulata', 'G. intercedens', 'G. cubicoides', 'G. pallidula', 'G. vicina', 'Marietta', 'G. modesta', 'G. infuscata', 'G. fraterna', 'G. acutocarinata', 'O. pagodiformis', 'G. torulosa', 'G. tabulata', 'G. subangulata', 'G. symmetrica', 'G. nigrocincta', 'G. tecta', 'O. marella', 'G. hybrida', 'G. fuscocincta', 'G. aterina', 'G. ebenum', 'G. auricoma', 'G. glabra', 'G. graminea', 'G. gibbosa', 'Sciota', 'Georgiana', 'G. abrupta', 'G. depygis', 'G. livescens', 'G. napella', 'G. torta', 'Cylindrella', 'G. virens', 'Newberryi', 'Newberryi', 'G. infantula', 'G. pulchella', 'M. depygis', 'G. cinerea', 'G. gracilior', 'G. translucens', 'Ovoidea', 'G. grata', 'G. quadricincta', 'G. grata', 'G. flava', 'G. tenebrovittata', 'G. tenera', 'G. pallescens', 'G. inosculata', 'G. circumlineata', 'G. parva', 'G. sordida', 'O. plebeia', 'G. castanea', 'G. adusta', 'Q. funebralis', 'G. furva', 'G. dubiosa', 'G. interlineata', 'G. brevispira', 'G. semicarinata', 'G. semicarinata', 'O. inornata', 'G. elaia', 'G. curvilabris', 'G. informis', 'G. vittatella', 'G. nigrina', 'G. rufescens', 'Virginica', 'G. sulcosa', 'Pleurocera', 'G. latitans', 'G. sculptilis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Goniobasis', 'Jleux rufa', 'Helix thyroides', 'H. thyroides', 'H. thyroides', 'H. rufa', 'H. thyroides', 'Helix rufa', 'Ii. thyroides', 'Subordo', 'Geomelania', 'Chittya', 'Truncatel ...

# %%
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
